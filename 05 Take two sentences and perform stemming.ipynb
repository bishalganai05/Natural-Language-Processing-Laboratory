# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from urllib import request
url="https://github.com/fbkarsdorp/python-course/raw/master/data/austen-emma.txt"
response=request.urlopen(url)
text=response.read().decode('utf8')
nltk.download('punkt')
ps=PorterStemmer()
tokenize=[sent_tokenize(text)[3],sent_tokenize(text)[4]]
for i in tokenize:
  for j in word_tokenize(i):
    print(j + ":" + ps.stem(j))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Sixteen:sixteen
# years:year
# had:had
# Miss:miss
# Taylor:taylor
# been:been
# in:in
# Mr.:mr.
# Woodhouse:woodhous
# 's:'s
# family:famili
# ,:,
# less:less
# as:as
# a:a
# governess:gover
# than:than
# a:a
# friend:friend
# ,:,
# very:veri
# fond:fond
# of:of
# both:both
# daughters:daughter
# ,:,
# but:but
# particularly:particularli
# of:of
# Emma:emma
# .:.
# Between:between
# _them_:_them_
# it:it
# was:wa
# more:more
# the:the
# intimacy:intimaci
# of:of
# sisters:sister
# .:.

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
nltk.download('punkt')

# Read the content of chesterton-thursday.txt
file_path = '/content/drive/MyDrive/chesterton-thursday.txt'


with open(file_path, 'r') as file:
    text = file.read()

# Tokenize the text into words
words = word_tokenize(text)

# Initialize the Porter Stemmer
porter = PorterStemmer()

# Perform stemming on each word
stemmed_words = [porter.stem(word) for word in words]

# Print the original and stemmed words
for i in range(min(5, len(words))):
    print(f"Original: {words[i]}, Stemmed: {stemmed_words[i]}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Original: [, Stemmed: [
# Original: The, Stemmed: the
# Original: Man, Stemmed: man
# Original: Who, Stemmed: who
# Original: Was, Stemmed: wa

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
