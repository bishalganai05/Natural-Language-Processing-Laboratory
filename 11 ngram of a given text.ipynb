# %%
import nltk
nltk.download('punkt')
text="Good morning everyone.Today we will study NLTK. Good afternoon everyone."
tokens = nltk.word_tokenize(text)
ngrams_list = list(nltk.ngrams(tokens,3))
print(ngrams_list)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [('Good', 'morning', 'everyone.Today'), ('morning', 'everyone.Today', 'we'), ('everyone.Today', 'we', 'will'), ('we', 'will', 'study'), ('will', 'study', 'NLTK'), ('study', 'NLTK', '.'), ('NLTK', '.', 'Good'), ('.', 'Good', 'afternoon'), ('Good', 'afternoon', 'everyone'), ('afternoon', 'everyone', '.')]
